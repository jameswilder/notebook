# %%
import tensorflow as tf
In [2]: tf.__version__
# Out:
# '1.3.0'

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/data/", one_hot=True)
# Out:
# Extracting /data/train-images-idx3-ubyte.gz
# Extracting /data/train-labels-idx1-ubyte.gz
# Extracting /data/t10k-images-idx3-ubyte.gz
# Extracting /data/t10k-labels-idx1-ubyte.gz

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

for i in range(10):
    digits = np.argmax(mnist.test.labels, 1)
    indexes = (digits == i)
    images = mnist.test.images[indexes][0:5]

    for j in range(5):   
        plt.subplot(5, 10, j * 10 + i + 1)
        plt.imshow(images[j].reshape(28, 28), cmap='gray')
        if j == 0:
            plt.title(i)
        plt.axis('off')
plt.show()

# %%
def weight_variable(shape):
  initial = tf.zeros(shape)
  return tf.Variable(initial)

def bias_variable(shape):
  initial = tf.zeros(shape)
  return tf.Variable(initial)

# %%
print('Initialising...')

input_size = 784
encode_dims = 10
hidden_size = 500

# input layer (MNIST digit)
x = tf.placeholder("float", [None, input_size])

# encoder
encoder_w1 = weight_variable([input_size, hidden_size])
encoder_b1 = bias_variable([hidden_size])
encoder_y1 = tf.nn.relu(tf.add(tf.matmul(x, encoder_w1), encoder_b1))

encoder_y1_noise = tf.random_normal(shape=tf.shape(encoder_y1), mean=0.0, stddev=0.00001, dtype=tf.float32) 

encoder_w2 = weight_variable([hidden_size, hidden_size])
encoder_b2 = bias_variable([hidden_size])
encoder_y2 = tf.nn.relu(tf.add(tf.matmul(tf.add(encoder_y1, encoder_y1_noise), encoder_w2), encoder_b2))

encoder_y2_noise = tf.random_normal(shape=tf.shape(encoder_y2), mean=0.0, stddev=0.00001, dtype=tf.float32) 

# encoded
encoder_w3 = weight_variable([hidden_size, encode_dims])
encoder_b3 = bias_variable([encode_dims])
z = tf.add(tf.matmul(tf.add(encoder_y2, encoder_y2_noise), encoder_w3), encoder_b3)

# decoder
decoder_w1 = weight_variable([encode_dims, hidden_size])
decoder_b1 = bias_variable([hidden_size])
decoder_y1 = tf.nn.relu(tf.add(tf.matmul(z, decoder_w1), decoder_b1))

decoder_y1_noise = tf.random_normal(shape=tf.shape(decoder_y1), mean=0.0, stddev=0.00001, dtype=tf.float32) 

decoder_w2 = weight_variable([hidden_size, hidden_size])
decoder_b2 = bias_variable([hidden_size])
decoder_y2 = tf.nn.relu(tf.add(tf.matmul(tf.add(decoder_y1, decoder_y1_noise), decoder_w2), decoder_b2))

decoder_y2_noise = tf.random_normal(shape=tf.shape(decoder_y2), mean=0.0, stddev=0.00001, dtype=tf.float32) 

# output (re-encoded MNIST digit)
decoder_w3 = weight_variable([hidden_size, input_size])
decoder_b3 = bias_variable([input_size])
y = tf.add(tf.matmul(tf.add(decoder_y2, decoder_y2_noise), decoder_w3), decoder_b3)

loss = tf.losses.mean_squared_error(y, x)

train_step = tf.train.AdamOptimizer(learning_rate=2e-3).minimize(loss)

init = tf.global_variables_initializer()

training_epochs = 100
batch_size = 50

batches_per_epoch = int(mnist.train.num_examples/batch_size)
print('{} batches per epoch'.format(batches_per_epoch))

total_batch_count = 0
last_fibonacci = 1
fibonacci = 1
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for epoch in range(training_epochs):
        for batch in range(batches_per_epoch):
            batch_images = mnist.train.next_batch(50)
            train_step.run(feed_dict={x: batch_images[0]})
            _, loss_ = sess.run([train_step, loss], feed_dict={x: batch_images[0]})

            total_batch_count = total_batch_count + 1
            is_fibonacci = (total_batch_count == fibonacci)
            finished = (epoch == training_epochs - 1) and (batch == batches_per_epoch - 1)
            if is_fibonacci or finished:
                test_loss, y_ = sess.run([loss, y], feed_dict={x: mnist.test.images})
                print('{}  {}  {:0.5f}  {:0.5f}'.format(epoch, batch, loss_, test_loss))
                for i in range(10):
                    digits = np.argmax(mnist.test.labels, 1)
                    idxs = (digits == i)
                    images =y_[idxs][0:5]
                    for j in range(5):   
                        plt.subplot(5, 10, i + j * 10 + 1)
                        plt.imshow(images[j].reshape(28, 28), cmap='gray')
                        if j == 0:
                            plt.title(i)
                        plt.axis('off')
                plt.show()
                if is_fibonacci:
                    temp = fibonacci
                    fibonacci = last_fibonacci + fibonacci
                    last_fibonacci = temp
# Out:
# Initialising...
# 1100 batches per epoch
# 0  0  0.10421  0.11291
# 0  1  0.11030  0.11187
# 0  2  0.10790  0.11085
# 0  4  0.10304  0.10885
# 0  7  0.09983  0.10606
# 0  12  0.09560  0.10198
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-11-aafbd117c833> in <module>()
#      78                     images =y_[idxs][0:5]
#      79                     for j in range(5):
# ---> 80                         plt.subplot(5, 10, i + j * 10 + 1)
#      81                         plt.imshow(images[j].reshape(28, 28), cmap='gray')
#      82                         if j == 0:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in subplot(*args, **kwargs)
#    1042
#    1043     fig = gcf()
# -> 1044     a = fig.add_subplot(*args, **kwargs)
#    1045     bbox = a.bbox
#    1046     byebye = []
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#    1019                     self._axstack.remove(ax)
#    1020
# -> 1021             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1022
#    1023         self._axstack.add(key, a)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_subplots.pyc in __init__(self, fig, *args, **kwargs)
#      71
#      72         # _axes_class is set in the subplot_class_factory
# ---> 73         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      74
#      75     def __reduce__(self):
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_base.pyc in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, axisbg, **kwargs)
#     549
#     550         self._connected = {}  # a dict from events to (id, func)
# --> 551         self.cla()
#     552         # funcs used to format x and y - fall back on major formatters
#     553         self.fmt_xdata = None
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_base.pyc in cla(self)
#     982         self.yaxis.cla()
#     983         for name, spine in six.iteritems(self.spines):
# --> 984             spine.cla()
#     985
#     986         self.ignore_existing_data_limits = True
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/spines.pyc in cla(self)
#     168         self._position = None  # clear position
#     169         if self.axis is not None:
# --> 170             self.axis.cla()
#     171
#     172     def is_frame_like(self):
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axis.pyc in cla(self)
#     758         self._set_artist_props(self.label)
#     759
# --> 760         self.reset_ticks()
#     761
#     762         self.converter = None
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axis.pyc in reset_ticks(self)
#     772         cbook.popall(self.minorTicks)
#     773
# --> 774         self.majorTicks.extend([self._get_tick(major=True)])
#     775         self.minorTicks.extend([self._get_tick(major=False)])
#     776         self._lastNumMajorTicks = 1
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axis.pyc in _get_tick(self, major)
#    2058         else:
#    2059             tick_kw = self._minor_tick_kw
# -> 2060         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2061
#    2062     def _get_label(self):
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     148         self.apply_tickdir(tickdir)
#     149
# --> 150         self.tick1line = self._get_tick1line()
#     151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axis.pyc in _get_tick1line(self)
#     555                           markeredgewidth=self._width,
#     556                           zorder=self._zorder)
# --> 557         l.set_transform(self.axes.get_yaxis_transform(which='tick1'))
#     558         self._set_artist_props(l)
#     559         return l
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_base.pyc in get_yaxis_transform(self, which)
#     784         elif which == 'tick1':
#     785             # for cartesian projection, this is bottom spine
# --> 786             return self.spines['left'].get_spine_transform()
#     787         elif which == 'tick2':
#     788             # for cartesian projection, this is top spine
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/spines.pyc in get_spine_transform(self)
#     404     def get_spine_transform(self):
#     405         """get the spine transform"""
# --> 406         self._ensure_position_is_set()
#     407         what, how = self._spine_transform
#     408
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/spines.pyc in _ensure_position_is_set(self)
#     150             # default position
#     151             self._position = ('outward', 0.0)  # in points
# --> 152             self.set_position(self._position)
#     153
#     154     def register_axis(self, axis):
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/spines.pyc in set_position(self, position)
#     394
#     395         if self.axis is not None:
# --> 396             self.axis.reset_ticks()
#     397         self.stale = True
#     398
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axis.pyc in reset_ticks(self)
#     773
#     774         self.majorTicks.extend([self._get_tick(major=True)])
# --> 775         self.minorTicks.extend([self._get_tick(major=False)])
#     776         self._lastNumMajorTicks = 1
#     777         self._lastNumMinorTicks = 1
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axis.pyc in _get_tick(self, major)
#    2058         else:
#    2059             tick_kw = self._minor_tick_kw
# -> 2060         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2061
#    2062     def _get_label(self):
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     148         self.apply_tickdir(tickdir)
#     149
# --> 150         self.tick1line = self._get_tick1line()
#     151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axis.pyc in _get_tick1line(self)
#     554                           markersize=self._size,
#     555                           markeredgewidth=self._width,
# --> 556                           zorder=self._zorder)
#     557         l.set_transform(self.axes.get_yaxis_transform(which='tick1'))
#     558         self._set_artist_props(l)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/lines.pyc in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     402         self._color = None
#     403         self.set_color(color)
# --> 404         self._marker = MarkerStyle()
#     405         self.set_marker(marker)
#     406
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/markers.pyc in __init__(self, marker, fillstyle)
#     184         # _recache() in set_marker.
#     185         self._fillstyle = fillstyle
# --> 186         self.set_marker(marker)
#     187         self.set_fillstyle(fillstyle)
#     188
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/markers.pyc in set_marker(self, marker)
#     270
#     271         self._marker = marker
# --> 272         self._recache()
#     273
#     274     def get_path(self):
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/markers.pyc in _recache(self)
#     198
#     199     def _recache(self):
# --> 200         self._path = Path(np.empty((0, 2)))
#     201         self._transform = IdentityTransform()
#     202         self._alt_path = None
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/path.pyc in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     160         self._codes = codes
#     161         self._interpolation_steps = _interpolation_steps
# --> 162         self._update_values()
#     163
#     164         if readonly:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/path.pyc in _update_values(self)
#     217         )
#     218         self._simplify_threshold = rcParams['path.simplify_threshold']
# --> 219         self._has_nonfinite = not np.isfinite(self._vertices).all()
#     220
#     221     @property
#
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.pyc in _all(a, axis, dtype, out, keepdims)
#      39
#      40 def _all(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 41     return umr_all(a, axis, dtype, out, keepdims)
#      42
#      43 def _count_reduce_items(arr, axis):
#
# KeyboardInterrupt:
